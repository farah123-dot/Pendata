# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Data Spesies Hewan dalam Genus yang sama
# Data dengan 2 kelas berbeda yaitu Panthera Tigris (Harimau) dan Panthera Leo (Singa), dengan 2 fitur yaitu Panjang Tubuh (cm) dan Berat Tubuh (kg)
#
# | No | Kelas             | Panjang Tubuh (cm) | Berat Tubuh (kg) |
# | -- | ----------------- | ------------------ | ---------------- |
# | 1  | Canis lupus       | 160                | 60              |
# | 2  | Canis lupus       | 155                | 58              |
# | 3  | Canis lupus       | 170                | 68              |
# | 4  | Canis lupus       | 165                | 65              |
# | 5  | Canis lupus       | 158                | 62              |
# | 6  | Canis familiaris  | 130                | 48              |
# | 7  | Canis familiaris  | 125                | 45              |
# | 8  | Canis familiaris  | 135                | 52              |
# | 9  | Canis familiaris  | 140                | 55              |
# | 10 | Canis familiaris  | 132                | 50              |
# | 11 | Canis lupus       | 168                | 66              |
# | 12 | Canis lupus       | 162                | 61              |
# | 13 | Canis familiaris  | 128                | 47              |
# | 14 | Canis lupus       | 157                | 60              |
# | 15 | Canis familiaris  | 138                | 53              |

# %% [markdown]
# ## Perhitungan Manual
# ###  1. Tentukan jumlah data berdasarkan kelas:
#
# Total data: 15
#
# * Canis lupus = 8
# * Canis familiaris = 7
#
#
# ### Fitur: Panjang Tubuh (cm)
#
# Data (urutan naik):
#
# | No | Panjang | Kelas            |
# | -- | ------- | ---------------- |
# | 7  | 125     | Canis familiaris |
# | 13 | 128     | Canis familiaris |
# | 6  | 130     | Canis familiaris |
# | 10 | 132     | Canis familiaris |
# | 8  | 135     | Canis familiaris |
# | 15 | 138     | Canis familiaris |
# | 9  | 140     | Canis familiaris |
# | 2  | 155     | Canis lupus      |
# | 5  | 158     | Canis lupus      |
# | 14 | 157     | Canis lupus      |
# | 12 | 162     | Canis lupus      |
# | 4  | 165     | Canis lupus      |
# | 11 | 168     | Canis lupus      |
# | 3  | 170     | Canis lupus      |
# | 1  | 160     | Canis lupus      |
#
# ###  3. Ambil contoh threshold split (misalnya):
#
# * Threshold = 155 cm
#
# Maka kita akan membagi:
#
# * Group Left (≤ 155)
# * Group Right (> 155)
#
# ###  4. Hitung Entropy Awal (sebelum split)
#
# $$
# Entropy(D) = -p_1 \log_2(p_1) - p_2 \log_2(p_2)
# $$
#
# $$
# p_1 = \frac{8}{15},\quad p_2 = \frac{7}{15}
# $$
#
# $$
# Entropy(D) = -\frac{8}{15} \log_2 \frac{8}{15} - \frac{7}{15} \log_2 \frac{7}{15} \approx 0.996
# $$
#
# ###  5. Entropy setelah split
#
# Group Left (≤ 155):
#
# * Data: No 7, 13, 6, 10, 8, 15, 9, 2 → 8 data
# * Kelas: 7 Canis familiaris, 1 Canis lupus
#
# $$
# Entropy(left) = -\frac{7}{8}\log_2\frac{7}{8} - \frac{1}{8}\log_2\frac{1}{8} \approx 0.543
# $$
#
# Group Right (> 155):
#
# * Data: No 5, 14, 12, 4, 11, 3, 1 → 7 data
# * Kelas: 7 Canis lupus
#
# $$
# Entropy(right) = -\frac{7}{7} \log_2 \frac{7}{7} = 0
# $$
#
# Information Gain:
#
# $$
# IG = Entropy(D) - \left( \frac{8}{15} \cdot 0.543 + \frac{7}{15} \cdot 0 \right) \approx 0.996 - 0.2896 \approx \boxed{0.7064}
# $$
#
# ###  6. Gini Index
#
# $$
# Gini(D) = 1 - \sum p_i^2 = 1 - \left(\frac{8}{15}\right)^2 - \left(\frac{7}{15}\right)^2 \approx 0.497
# $$
#
# Group Left (≤ 155):
#
# * 7 Canis familiaris, 1 Canis lupus
#
# $$
# Gini(left) = 1 - \left(\frac{7}{8}\right)^2 - \left(\frac{1}{8}\right)^2 = 1 - 0.765625 - 0.015625 = 0.21875
# $$
#
# Group Right (> 155):
#
# * 7 Canis lupus
#
# $$
# Gini(left) = 1 - \left(\frac{7}{7}\right)^2 = 1 - 1 = 0
# $$
#
# Gini Split:
#
# $$
# Gini_{split} = \frac{8}{15} \cdot 0.21875 + \frac{7}{15} \cdot 0 = \boxed{0.116}
# $$
#
# ### Hasil Sementara untuk Fitur "Panjang Tubuh":
#
# | Ukuran Evaluasi  | Nilai     |
# | ---------------- | --------- |
# | Entropy Awal     | 0.996     |
# | Information Gain | 0.706     |
# | Gini Split       | 0.116     |

# %% [markdown]
# ###  Fitur: Berat Tubuh (kg)
#
# ###  1. Urutkan data berdasarkan Berat Tubuh
#
# | No | Berat (kg) | Kelas            |
# | -- | ---------- | ---------------- |
# | 7  | 45         | Canis familiaris |
# | 13 | 47         | Canis familiaris |
# | 6  | 48         | Canis familiaris |
# | 10 | 50         | Canis familiaris |
# | 8  | 52         | Canis familiaris |
# | 15 | 53         | Canis familiaris |
# | 9  | 55         | Canis familiaris |
# | 2  | 58         | Canis lupus      |
# | 1  | 60         | Canis lupus      |
# | 14 | 60         | Canis lupus      |
# | 12 | 61         | Canis lupus      |
# | 5  | 62         | Canis lupus      |
# | 4  | 65         | Canis lupus      |
# | 11 | 66         | Canis lupus      |
# | 3  | 68         | Canis lupus      |
#
#
# ###  2. Ambil threshold split (contoh):
#
# Gunakan threshold = 58 kg (terjadi perpindahan mayoritas dari *familiaris* ke *lupus*)
#
# #### Maka:
#
# * Group Left (≤ 58) = data dengan berat ≤ 58 kg (No: 7, 13, 6, 10, 8, 15, 9, 2) → 8 data
# * Group Right (> 58) = sisanya (No: 1, 14, 12, 5, 4, 11, 3) → 7 data
#
#
# ###  3. Komposisi kelas:
#
# Sebelum split:
#
# * 8 *Canis lupus*
# * 7 *Canis familiaris*
#
#
# $$
# Entropy(D) = -\frac{8}{15} \log_2 \frac{8}{15} - \frac{7}{15} \log_2 \frac{7}{15} \approx 0.996
# $$
#
#
# ###  4. Entropy setelah split:
#
# #### Group Left (≤ 58 kg):
#
# * 7 *Canis familiaris* : No 7, 13, 6, 10, 8, 15, 9
# * 1 *Canis lupus* : No 2
#
# $$
# Entropy(left) = -\frac{7}{8} \log_2 \frac{7}{8} - \frac{1}{8} \log_2 \frac{1}{8} \approx 0.543
# $$
#
# #### Group Right (> 58 kg):
#
#
# * 7 *Canis lupus*: No 1, 14, 12, 5, 4, 11, 3
#
#
# $$
# Entropy(right) = -\frac{7}{7} \log_2 \frac{7}{7} = 0
# $$
#
#
# ###  5. Information Gain
#
# $$
# IG = Entropy(D) - \left( \frac{8}{15} \cdot 0.543 + \frac{7}{15} \cdot 0 \right) \approx 0.996 - 0.2896 \approx \boxed{0.7064}
# $$
#
#
# ###  6. Gini Index
#
# $$
# Gini(D) = 1 - \left(\frac{8}{15}\right)^2 - \left(\frac{7}{15}\right)^2 \approx 0.497
# $$
#
# #### Gini(Left):
#
# $$
# Gini(left) = 1 - \left(\frac{7}{8}\right)^2 - \left(\frac{1}{8}\right)^2 = 1 - 0.765625 - 0.015625 = 0.21875
# $$
#
# #### Gini(Right):
#
# Semua satu kelas → Gini = 0
#
# #### Gini Split:
#
# $$
# Gini_{split} = \frac{8}{15} \cdot 0.21875 + \frac{7}{15} \cdot 0 = \boxed{0.116}
# $$
#
#
# ## Hasil Akhir Fitur "Berat Tubuh"
#
# | Ukuran Evaluasi  | Nilai     |
# | ---------------- | --------- |
# | Entropy Awal     | 0.996     |
# | Information Gain | 0.706     |
# | Gini Split       | 0.116     |

# %% [markdown]
# ## Kesimpulan Perbandingan Dua Fitur:
#
# | Fitur         | Information Gain | Gini Index |
# | ------------- | ---------------- | ---------- |
# | Panjang Tubuh | 0.706            | 0.116      |
# | Berat Tubuh   | 0.706            | 0.116      |

# %% [markdown]
# ## Visualisasi Decision Tree

# %% [markdown]
# Ini adalah code program untuk mencari decision tree sekaligus rules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.preprocessing import LabelEncoder

# === Data ===
data = {
    "Panjang Tubuh (cm)": [175, 155, 170, 165, 158, 130, 125, 135, 140, 132, 168, 162, 128, 157, 138],
    "Berat Tubuh (kg)": [60, 58, 68, 65, 62, 48, 45, 52, 55, 50, 66, 61, 47, 60, 53],
    "Kelas": [
        "Canis lupus", "Canis lupus", "Canis lupus", "Canis lupus", "Canis lupus",
        "Canis familiaris", "Canis familiaris", "Canis familiaris", "Canis familiaris", "Canis familiaris",
        "Canis lupus", "Canis lupus", "Canis familiaris", "Canis lupus", "Canis familiaris"
    ]
}
df = pd.DataFrame(data)

# === Label Encoding ===
le = LabelEncoder()
df['Label'] = le.fit_transform(df['Kelas'])  # lupus=1, familiaris=0

# === Fitur dan Target ===
X = df[["Panjang Tubuh (cm)", "Berat Tubuh (kg)"]]
y = df["Label"]  # <- gunakan label numerik hasil encoding

# === Train Decision Tree ===
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
clf.fit(X, y)

# === 1. Tampilkan Pohon Keputusan ===
print("\n=== Pohon Keputusan (Decision Tree) ===")
tree_rules = export_text(clf, feature_names=list(X.columns))
print(tree_rules)
# Out:
# === Pohon Keputusan (Decision Tree) ===
# |--- Panjang Tubuh (cm) <= 147.50
# |   |--- class: 0
# |--- Panjang Tubuh (cm) >  147.50
# |   |--- class: 1

# %% [markdown]
# ## Rules

# %% [markdown]
# ## Visualisasi Splitting

# %%
# === Uji 2 Data Baru ===
uji_baru = pd.DataFrame({
    'Panjang Tubuh (cm)': [130, 170],
    'Berat Tubuh (kg)': [48, 68]
})

prediksi = clf.predict(uji_baru)
hasil = le.inverse_transform(prediksi)

print("\n=== Prediksi 2 Data Baru ===")
for i, (p, b) in enumerate(zip(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'])):
    print(f"Data {i+1}: Panjang={p}, Berat={b} → Prediksi: {hasil[i]}")

# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"
plot_step = 1.0

x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary (Panjang vs Berat)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Prediksi 2 Data Baru ===
# Data 1: Panjang=130, Berat=48 → Prediksi: Canis familiaris
# Data 2: Panjang=170, Berat=68 → Prediksi: Canis lupus
#
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Splitting Setelah ada 2 Data Baru

# %%
# === Visualisasi Decision Boundary ===
print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"
plot_step = 1.0

x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

# Plot data uji
plt.scatter(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'],
            c='black', marker='X', s=100, label='Data Uji')

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary (Panjang vs Berat)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ## Visualisasi Decision Tree dalam bentuk gambar

# %%
# === Visualisasi Struktur Pohon ===
plt.figure(figsize=(12, 3))
plot_tree(
    clf,
    feature_names=["Panjang Tubuh (cm)", "Berat Tubuh (kg)"],
    class_names=le.classes_,  # gunakan label string hasil encoding
    filled=True,
    rounded=True,
    impurity=True  # tampilkan nilai Gini
)
plt.title("Decision Tree untuk Panthera tigris vs Panthera leo")
plt.tight_layout()
plt.show()

# %%
print("=== Rules ===")
print("RULE 1: Jika Panjang <= 147.5 Maka Kelas = Canis familiaris")
print("Rule 2: Jika Panjang > 147.5 Maka Kelas = Canis lupus")
# Out:
# === Rules ===
# RULE 1: Jika Panjang <= 147.5 Maka Kelas = Canis familiaris
# Rule 2: Jika Panjang > 147.5 Maka Kelas = Canis lupus
